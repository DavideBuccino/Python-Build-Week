# %%
import os
import pandas as pd
from bs4 import BeautifulSoup

# leggi il file html salvato
with open(r"C:\Users\Lenovo\OneDrive\Documenti\Python\Build week Python\Sorgente Alex\SCARPE_SPORTIVE_UNDER_ARMOUR_PAGINA_1.html", "r", encoding="utf-8") as file:
    html = file.read()

# parsing dell'html
soup = BeautifulSoup(html, 'html.parser')

# assegnazione categoria in base al nome del file html salvato
categoria = "Scarpini Sportivi Under Armour"

# inizializzazione prodotti
prodotti = []

# scraping div
div_prodotti = soup.find_all('div', class_='_0xLoFW _78xIQ- EJ4MLB f4ql6o JT3_zV')

# ciclo per estrarre i dati dei prodotti da div_prodotti
for div_prodotto in div_prodotti:
    try:
        # url prodotto
        link = div_prodotto.find('a', class_='q84f1m CKDt_l LyRfpJ JT3_zV CKDt_l _2dqvZS')
        if not link or 'href' not in link.attrs:
            continue  # salta questo prodotto se manca l'URL
        url_prodotto = link['href']
        
        # marca e nome prodotto
        marca_tag = div_prodotto.find('h3', class_='OBkCPz lystZ1 m3OCL3 HlZ_Tf ja2E95 IvrHht ZkIJC- u-kVXO')
        if not marca_tag:
            continue  # salta se manca la marca
        marca = marca_tag.text.strip().upper()

        # nome prodotto
        nome_prodotto = div_prodotto.find('h3', class_='voFjEy lystZ1 m3OCL3 HlZ_Tf ja2E95 IvrHht ZkIJC- u-kVXO').text.strip()
        
        # inizializza i prezzi
        prezzo = "N/A"
        prezzo_ordinario = "N/A"
        
        # cerca prezzo corrente (indipendentemente dal prezzo ordinario)
        # cerca prima nel formato standard
        prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 Sb5G3D HlZ_Tf')
        if not prezzo_tag:
            # cerca su altri formati di prezzo
            prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 Sb5G3D Km7l2y')
        if not prezzo_tag:
            prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 m3OCL3 HlZ_Tf')
        
        if prezzo_tag:
            prezzo = prezzo_tag.text.strip().replace('€', '').strip()
        
        # cerca prezzo ordinario (solo se esiste)
        # cerca la sezione che contiene "prezzo ordinario"
        for p_tag in div_prodotto.find_all('p', class_='voFjEy _2kjxJ6 m3OCL3 HlZ_Tf _0xLoFW u9KIT8 _7ckuOK vSgP6A'):
            if 'Prezzo ordinario:' in p_tag.text:
                # prendi il primo span con il prezzo dopo il testo "prezzo ordinario"
                for span in p_tag.find_all('span', class_='voFjEy goVnUa m3OCL3 Yb63TQ'):
                    if 'Prezzo ordinario:' not in span.text:
                        prezzo_ordinario = span.text.strip().replace('€', '').strip()
                        break
                # se non trovato, prova con la classe alternativa
                if prezzo_ordinario == "N/A":
                    for span in p_tag.find_all('span', class_='voFjEy goVnUa m3OCL3 Yb63TQ ZiDB59 uVxVjw'):
                        prezzo_ordinario = span.text.strip().replace('€', '').strip()
                        break

        if prezzo_ordinario == "N/A":
            prezzo_ordinario = prezzo

        # se la marca è fra le 4 note, aggiungi i dati alla lista/dizionario
        if marca in ['UNDER ARMOUR']:
            prodotti.append({
                "categoria": categoria,
                "marca": marca.upper(),
                "nome_prodotto": nome_prodotto,
                "prezzo_effettivo": prezzo,
                "prezzo_ordinario": prezzo_ordinario, 
                "url_prodotto": url_prodotto,
            })
            
    except Exception as e:
        print(f"Errore durante l'elaborazione: {str(e)}")
        continue


# crea dataframe
df_temp = pd.DataFrame(prodotti)

df_temp.to_csv('Under Armour.csv', index= False, encoding='utf-8')

# visualizza dataframe
display(df_temp)
# Out:
#                          categoria         marca  \
# 0   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 1   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 2   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 3   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 4   Scarpini Sportivi Under Armour  UNDER ARMOUR
# ..                             ...           ...
# 79  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 80  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 81  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 82  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 83  Scarpini Sportivi Under Armour  UNDER ARMOUR
#
#                                         nome_prodotto prezzo_effettivo  \
# 0   CHARGED COMMIT TR 4 - Scarpe da allenamento - ...            67,99
# 1   REIGN 6 - Scarpe da allenamento - anthracite/b...           118,99
# 2             REIGN 6 - Scarpe da allenamento - black           139,99
# 3            COURT 96 - Scarpe da allenamento - black            69,99
# 4   PHANTOM 4 UNISEX - Scarpe da corsa su strada -...           130,00
# ..                                                ...              ...
# 79  INFINITE PRO 2 - Scarpe da corsa su strada - w...           129,99
# 80  MAGNETICO ELITE 4 - Scarpe da calcetto con tac...           249,99
# 81           IGNITE SELECT - Ciabatte da mare - white            28,00
# 82  MAGNETICO SELECT 4 FG - Scarpe da calcetto con...            79,99
# 83  MAGNETICO ELITE 4 FG - Scarpe da calcetto con ...           209,96
#
#    prezzo_ordinario                                       url_prodotto
# 0             79,99  https://www.zalando.it/under-armour-charged-co...
# 1            139,99  https://www.zalando.it/under-armour-tribase-re...
# 2            139,99  https://www.zalando.it/under-armour-tribase-re...
# 3             99,99  https://www.zalando.it/under-armour-sport-cour...
# 4            130,00  https://www.zalando.it/under-armour-scarpe-da-...
# ..              ...                                                ...
# 79           129,99  https://www.zalando.it/under-armour-infinite-p...
# 80           249,99  https://www.zalando.it/under-armour-magnetico-...
# 81            28,00  https://www.zalando.it/under-armour-ignite-sel...
# 82            79,99  https://www.zalando.it/under-armour-magnetico-...
# 83           249,95  https://www.zalando.it/under-armour-stivaletti...
#
# [84 rows x 6 columns]

# %%
# leggi il file html salvato
with open(r"C:\Users\Lenovo\OneDrive\Documenti\Python\Build week Python\Sorgente Alex\SCARPE_SPORTIVE_UNDER_ARMOUR_PAGINA_2.html", "r", encoding="utf-8") as file:
    html = file.read()

# parsing dell'html
soup = BeautifulSoup(html, 'html.parser')

# assegnazione categoria in base al nome del file html salvato
categoria = "Scarpini Sportivi Under Armour"

# inizializzazione prodotti
prodotti = []

# scraping div
div_prodotti = soup.find_all('div', class_='_0xLoFW _78xIQ- EJ4MLB f4ql6o JT3_zV')

# ciclo per estrarre i dati dei prodotti da div_prodotti
for div_prodotto in div_prodotti:
    try:
        # url prodotto
        link = div_prodotto.find('a', class_='q84f1m CKDt_l LyRfpJ JT3_zV CKDt_l _2dqvZS')
        if not link or 'href' not in link.attrs:
            continue  # salta questo prodotto se manca l'URL
        url_prodotto = link['href']
        
        # marca e nome prodotto
        marca_tag = div_prodotto.find('h3', class_='OBkCPz lystZ1 m3OCL3 HlZ_Tf ja2E95 IvrHht ZkIJC- u-kVXO')
        if not marca_tag:
            continue  # salta se manca la marca
        marca = marca_tag.text.strip().upper()

        # nome prodotto
        nome_prodotto = div_prodotto.find('h3', class_='voFjEy lystZ1 m3OCL3 HlZ_Tf ja2E95 IvrHht ZkIJC- u-kVXO').text.strip()
        
        # inizializza i prezzi
        prezzo = "N/A"
        prezzo_ordinario = "N/A"
        
        # cerca prezzo corrente (indipendentemente dal prezzo ordinario)
        # cerca prima nel formato standard
        prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 Sb5G3D HlZ_Tf')
        if not prezzo_tag:
            # cerca su altri formati di prezzo
            prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 Sb5G3D Km7l2y')
        if not prezzo_tag:
            prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 m3OCL3 HlZ_Tf')
        
        if prezzo_tag:
            prezzo = prezzo_tag.text.strip().replace('€', '').strip()
        
        # cerca prezzo ordinario (solo se esiste)
        # cerca la sezione che contiene "prezzo ordinario"
        for p_tag in div_prodotto.find_all('p', class_='voFjEy _2kjxJ6 m3OCL3 HlZ_Tf _0xLoFW u9KIT8 _7ckuOK vSgP6A'):
            if 'Prezzo ordinario:' in p_tag.text:
                # prendi il primo span con il prezzo dopo il testo "prezzo ordinario"
                for span in p_tag.find_all('span', class_='voFjEy goVnUa m3OCL3 Yb63TQ'):
                    if 'Prezzo ordinario:' not in span.text:
                        prezzo_ordinario = span.text.strip().replace('€', '').strip()
                        break
                # se non trovato, prova con la classe alternativa
                if prezzo_ordinario == "N/A":
                    for span in p_tag.find_all('span', class_='voFjEy goVnUa m3OCL3 Yb63TQ ZiDB59 uVxVjw'):
                        prezzo_ordinario = span.text.strip().replace('€', '').strip()
                        break

        if prezzo_ordinario == "N/A":
            prezzo_ordinario = prezzo
        
        # se la marca è fra le 4 note, aggiungi i dati alla lista/dizionario
        if marca in ['UNDER ARMOUR']:
            prodotti.append({
                "categoria": categoria,
                "marca": marca.upper(),
                "nome_prodotto": nome_prodotto,
                "prezzo_effettivo": prezzo,
                "prezzo_ordinario": prezzo_ordinario, 
                "url_prodotto": url_prodotto,
            })
            
    except Exception as e:
        print(f"Errore durante l'elaborazione: {str(e)}")
        continue

# crea dataframe
df_temp1 = pd.DataFrame(prodotti)

df_temp1.to_csv('Under Armour1.csv', index= False, encoding='utf-8')

# visualizza dataframe
display(df_temp1)
# Out:
#                          categoria         marca  \
# 0   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 1   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 2   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 3   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 4   Scarpini Sportivi Under Armour  UNDER ARMOUR
# ..                             ...           ...
# 79  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 80  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 81  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 82  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 83  Scarpini Sportivi Under Armour  UNDER ARMOUR
#
#                                         nome_prodotto prezzo_effettivo  \
# 0   MAGNETICO SELECT 4 FG - Scarpe da calcetto con...            79,99
# 1   VISUAL CUSH FORGE UNISEX - Scarpe da corsa su ...            90,97
# 2   INFINITE PRO 2 - Scarpe da corsa su strada - b...           129,99
# 3   FLOW FUTR X UNISEX - Scarpe da basket - black/...           119,99
# 4     SPAWN 6 MID - Scarpe da basket - mod gray (100)           120,00
# ..                                                ...              ...
# 79                 JET '23 - Scarpe da basket - black            52,00
# 80  Scarpe da corsa su strada - white distant gray...            95,97
# 81  INFINITE PRO - Scarpe da corsa su strada - sum...            77,97
# 82                  Scarpe da corsa su strada - white            95,97
# 83  APPARITION - Scarpe da allenamento - coyote/co...            64,99
#
#    prezzo_ordinario                                       url_prodotto
# 0             79,99  https://www.zalando.it/under-armour-magnetico-...
# 1            130,00  https://www.zalando.it/under-armour-sneakers-b...
# 2            129,99  https://www.zalando.it/under-armour-infinite-p...
# 3            119,99  https://www.zalando.it/under-armour-flow-futr-...
# 4            120,00  https://www.zalando.it/under-armour-performanc...
# ..              ...                                                ...
# 79            65,00  https://www.zalando.it/under-armour-performanc...
# 80           160,00  https://www.zalando.it/under-armour-scarpe-run...
# 81           130,00  https://www.zalando.it/under-armour-infinite-p...
# 82           160,00  https://www.zalando.it/under-armour-scarpe-run...
# 83           129,99  https://www.zalando.it/under-armour-hovr-appar...
#
# [84 rows x 6 columns]

# %%
# leggi il file html salvato
with open(r"C:\Users\Lenovo\OneDrive\Documenti\Python\Build week Python\Sorgente Alex\SCARPE_SPORTIVE_UNDER_ARMOUR_PAGINA_3.html", "r", encoding="utf-8") as file:
    html = file.read()

# parsing dell'html
soup = BeautifulSoup(html, 'html.parser')

# assegnazione categoria in base al nome del file html salvato
categoria = "Scarpini Sportivi Under Armour"
# inizializzazione prodotti
prodotti = []

# scraping div
div_prodotti = soup.find_all('div', class_='_0xLoFW _78xIQ- EJ4MLB f4ql6o JT3_zV')

# ciclo per estrarre i dati dei prodotti da div_prodotti
for div_prodotto in div_prodotti:
    try:
        # url prodotto
        link = div_prodotto.find('a', class_='q84f1m CKDt_l LyRfpJ JT3_zV CKDt_l _2dqvZS')
        if not link or 'href' not in link.attrs:
            continue  # salta questo prodotto se manca l'URL
        url_prodotto = link['href']
        
        # marca e nome prodotto
        marca_tag = div_prodotto.find('h3', class_='OBkCPz lystZ1 m3OCL3 HlZ_Tf ja2E95 IvrHht ZkIJC- u-kVXO')
        if not marca_tag:
            continue  # salta se manca la marca
        marca = marca_tag.text.strip().upper()

        # nome prodotto
        nome_prodotto = div_prodotto.find('h3', class_='voFjEy lystZ1 m3OCL3 HlZ_Tf ja2E95 IvrHht ZkIJC- u-kVXO').text.strip()
        
        # inizializza i prezzi
        prezzo = "N/A"
        prezzo_ordinario = "N/A"
        
        # cerca prezzo corrente (indipendentemente dal prezzo ordinario)
        # cerca prima nel formato standard
        prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 Sb5G3D HlZ_Tf')
        if not prezzo_tag:
            # cerca su altri formati di prezzo
            prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 Sb5G3D Km7l2y')
        if not prezzo_tag:
            prezzo_tag = div_prodotto.find('span', class_='voFjEy lystZ1 m3OCL3 HlZ_Tf')
        
        if prezzo_tag:
            prezzo = prezzo_tag.text.strip().replace('€', '').strip()
        
        # cerca prezzo ordinario (solo se esiste)
        # cerca la sezione che contiene "prezzo ordinario"
        for p_tag in div_prodotto.find_all('p', class_='voFjEy _2kjxJ6 m3OCL3 HlZ_Tf _0xLoFW u9KIT8 _7ckuOK vSgP6A'):
            if 'Prezzo ordinario:' in p_tag.text:
                # prendi il primo span con il prezzo dopo il testo "prezzo ordinario"
                for span in p_tag.find_all('span', class_='voFjEy goVnUa m3OCL3 Yb63TQ'):
                    if 'Prezzo ordinario:' not in span.text:
                        prezzo_ordinario = span.text.strip().replace('€', '').strip()
                        break
                # se non trovato, prova con la classe alternativa
                if prezzo_ordinario == "N/A":
                    for span in p_tag.find_all('span', class_='voFjEy goVnUa m3OCL3 Yb63TQ ZiDB59 uVxVjw'):
                        prezzo_ordinario = span.text.strip().replace('€', '').strip()
                        break

        if prezzo_ordinario == "N/A":
            prezzo_ordinario = prezzo
        
        # se la marca è fra le 4 note, aggiungi i dati alla lista/dizionario
        if marca in ['UNDER ARMOUR']:
            prodotti.append({
                "categoria": categoria,
                "marca": marca.upper(),
                "nome_prodotto": nome_prodotto,
                "prezzo_effettivo": prezzo,
                "prezzo_ordinario": prezzo_ordinario, 
                "url_prodotto": url_prodotto,
            })
            
    except Exception as e:
        print(f"Errore durante l'elaborazione: {str(e)}")
        continue

# crea dataframe
df_temp2 = pd.DataFrame(prodotti)

df_temp2.to_csv('Under Armour2.csv', index= False, encoding='utf-8')

# visualizza dataframe
display(df_temp2)
# Out:
#                          categoria         marca  \
# 0   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 1   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 2   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 3   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 4   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 5   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 6   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 7   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 8   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 9   Scarpini Sportivi Under Armour  UNDER ARMOUR
# 10  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 11  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 12  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 13  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 14  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 15  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 16  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 17  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 18  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 19  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 20  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 21  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 22  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 23  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 24  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 25  Scarpini Sportivi Under Armour  UNDER ARMOUR
#
#                                         nome_prodotto prezzo_effettivo  \
# 0   INFINITE PRO - Scarpe da corsa su strada - car...            77,97
# 1   CHARGED BANDIT TR 3 - Scarpe da trail running ...            79,97
# 2                  CURRY - Scarpe da basket - white l           150,00
# 3                    Scarpe da allenamento - grn vert            48,75
# 4   APPARITION - Scarpe da allenamento - coyote/co...            64,99
# 5                  JET '23 - Scarpe da basket - black            52,00
# 6               LOCKDOWN 7 - Scarpe da basket - white            75,00
# 7   PERFORMANCE SPAWN 6 CAMO - Scarpe da basket - ...            69,97
# 8   CHARGED PURSUIT 3 - Scarpe da corsa su strada ...            65,00
# 9             UNISEX  - Scarpe da allenamento - black            89,97
# 10                        Scarpe da camminata - black           100,00
# 11  SHADOW ELITE 2.0 FG - Scarpe da calcetto con t...           193,17
# 12  Scarpe da corsa su strada - white distant gray...            95,97
# 13  PHANTOM 4 STORM - Scarpe da allenamento - dist...           126,99
# 14  CLONE MAGNETICO PRO3.0 FG - Scarpe da calcetto...           109,16
# 15  COURT PERFORMANCE FLOW FUTR X ELITE LUX - Scar...            89,97
# 16          CURRY 4 FLOTRO - Scarpe da basket - black           140,00
# 17  SHADOW TURF 2.0 - Scarpe da calcetto con tacch...            43,99
# 18  CURRY 11 MOUTHGUARD - Scarpe da basket - sky blue           170,00
# 19  MAGNETICO SELECT 4 FG - Scarpe da calcetto con...            43,99
# 20                LOCKDOWN 7 - Scarpe da basket - red            75,00
# 21                  JET '23 - Scarpe da basket - gray            56,00
# 22        CHARGED DRAW 2 - Scarpe da golf - halo gray           107,97
# 23  CURRY CHAMPION MINDSET - Scarpe da basket - le...           149,00
# 24              LOCKDOWN 7 - Scarpe da basket - black            90,90
# 25     FLOW FUTR X 4 - Scarpe da basket - black/white           101,99
#
#    prezzo_ordinario                                       url_prodotto
# 0            130,00  https://www.zalando.it/under-armour-infinite-p...
# 1            100,00  https://www.zalando.it/under-armour-charged-ba...
# 2            150,00  https://www.zalando.it/under-armour-sneakers-b...
# 3             48,75  https://www.zalando.it/under-armour-sneakers-b...
# 4            129,99  https://www.zalando.it/under-armour-hovr-appar...
# 5             65,00  https://www.zalando.it/under-armour-performanc...
# 6             75,00  https://www.zalando.it/under-armour-performanc...
# 7            100,00  https://www.zalando.it/under-armour-performanc...
# 8             65,00  https://www.zalando.it/under-armour-charged-pu...
# 9            150,00  https://www.zalando.it/under-armour-sneakers-b...
# 10           100,00  https://www.zalando.it/under-armour-scarpe-run...
# 11           229,95  https://www.zalando.it/under-armour-shadow-eli...
# 12           160,00  https://www.zalando.it/under-armour-scarpe-run...
# 13           149,99  https://www.zalando.it/under-armour-phantom-4-...
# 14           129,95  https://www.zalando.it/under-armour-clone-magn...
# 15           150,00  https://www.zalando.it/under-armour-court-perf...
# 16           140,00  https://www.zalando.it/under-armour-curry-flot...
# 17            79,99  https://www.zalando.it/under-armour-shadow-tur...
# 18           170,00  https://www.zalando.it/under-armour-scarpe-da-...
# 19            79,99  https://www.zalando.it/under-armour-magnetico-...
# 20            75,00  https://www.zalando.it/under-armour-performanc...
# 21            80,00  https://www.zalando.it/under-armour-jet-23-sca...
# 22           120,00  https://www.zalando.it/under-armour-under-armo...
# 23           170,00  https://www.zalando.it/under-armour-scarpe-da-...
# 24            90,90  https://www.zalando.it/under-armour-court-perf...
# 25           119,99  https://www.zalando.it/under-armour-scarpe-da-...

# %%
file_list = ['Under Armour.csv', 'Under armour1.csv', 'Under Armour2.csv']

df_completo = pd.concat([pd.read_csv(file, encoding='utf-8') for file in file_list], ignore_index=True)

df_completo.to_csv('Under Armour Unito.csv', index=False)

df_completo
# Out:
#                           categoria         marca  \
# 0    Scarpini Sportivi Under Armour  UNDER ARMOUR
# 1    Scarpini Sportivi Under Armour  UNDER ARMOUR
# 2    Scarpini Sportivi Under Armour  UNDER ARMOUR
# 3    Scarpini Sportivi Under Armour  UNDER ARMOUR
# 4    Scarpini Sportivi Under Armour  UNDER ARMOUR
# ..                              ...           ...
# 189  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 190  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 191  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 192  Scarpini Sportivi Under Armour  UNDER ARMOUR
# 193  Scarpini Sportivi Under Armour  UNDER ARMOUR
#
#                                          nome_prodotto prezzo_effettivo  \
# 0    CHARGED COMMIT TR 4 - Scarpe da allenamento - ...            67,99
# 1    REIGN 6 - Scarpe da allenamento - anthracite/b...           118,99
# 2              REIGN 6 - Scarpe da allenamento - black           139,99
# 3             COURT 96 - Scarpe da allenamento - black            69,99
# 4    PHANTOM 4 UNISEX - Scarpe da corsa su strada -...           130,00
# ..                                                 ...              ...
# 189                  JET '23 - Scarpe da basket - gray            56,00
# 190        CHARGED DRAW 2 - Scarpe da golf - halo gray           107,97
# 191  CURRY CHAMPION MINDSET - Scarpe da basket - le...           149,00
# 192              LOCKDOWN 7 - Scarpe da basket - black            90,90
# 193     FLOW FUTR X 4 - Scarpe da basket - black/white           101,99
#
#     prezzo_ordinario                                       url_prodotto
# 0              79,99  https://www.zalando.it/under-armour-charged-co...
# 1             139,99  https://www.zalando.it/under-armour-tribase-re...
# 2             139,99  https://www.zalando.it/under-armour-tribase-re...
# 3              99,99  https://www.zalando.it/under-armour-sport-cour...
# 4             130,00  https://www.zalando.it/under-armour-scarpe-da-...
# ..               ...                                                ...
# 189            80,00  https://www.zalando.it/under-armour-jet-23-sca...
# 190           120,00  https://www.zalando.it/under-armour-under-armo...
# 191           170,00  https://www.zalando.it/under-armour-scarpe-da-...
# 192            90,90  https://www.zalando.it/under-armour-court-perf...
# 193           119,99  https://www.zalando.it/under-armour-scarpe-da-...
#
# [194 rows x 6 columns]

# %%
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import json

url = "https://www.zalando.it/scarpe-sportive-uomo/under-armour/"
driver = webdriver.Chrome()
driver.get(url)
html = driver.page_source
driver.close()
soup = BeautifulSoup(html, 'html.parser')

s = soup.find("script", attrs={"id": "re-concurrent-data-hydrate"})
s = s.text.replace("window.__hydrationDataConsume(", "")[:-1]
d = json.loads(s)

taglie_prodotti = []
for p in list(d["graphqlCache"].values()):
    if "product" in p["data"]:
        nome = p["data"]["product"]["name"]
        taglie_disponibili = []
        if "simples" in p["data"]["product"]:
            for t in p["data"]["product"]["simples"]:
                taglie_disponibili.append(t["size"])
        else:
            taglie_disponibili = None
        taglie_prodotti.append({"nome_prodotto": nome, "taglie": taglie_disponibili})

df_taglie = pd.DataFrame(taglie_prodotti)
df_taglie
print("DataFrame df_taglie:")
print(df_taglie)
# Out:
# DataFrame df_taglie:
#                                         nome_prodotto  \
# 0   REIGN 6 - Scarpe da allenamento - anthracite/b...
# 1   CHARGED COMMIT TR 4 - Scarpe da allenamento - ...
# 2            COURT 96 - Scarpe da allenamento - black
# 3             REIGN 6 - Scarpe da allenamento - black
# 4   Scarpe da corsa su strada - black anthracite c...
# 5   PHANTOM 4 UNISEX - Scarpe da corsa su strada -...
# 6   CHARGED SPEED SWIFT - Scarpe da allenamento - ...
# 7          APPARITION - Scarpe da allenamento - white
# 8    CHARGED SURGE 4 - Scarpe da allenamento - bianco
# 9   FAT TIRE VENTURE PRO UNISEX - Scarpe da allena...
# 10  APPARITION - Scarpe da allenamento - white/cas...
# 11  REIGN 6 - Scarpe da allenamento - hydro green ...
# 12  CHARGED EDGE FITNESS - Scarpe da allenamento -...
# 13  CHARGED COMMIT TR 4 - Scarpe da allenamento - ...
# 14   APPARITION - Scarpe da allenamento - hydro green
# 15  APPARITION - Scarpe da allenamento - black/met...
# 16  PHANTOM 4 UNISEX - Scarpe da corsa su strada -...
# 17  CHARGED BANDIT TR 3 - Scarpe da corsa su strad...
# 18       INFINITE - Scarpe da corsa su strada - black
# 19  CHARGED BANDIT TR 3 - Scarpe da corsa su strad...
# 20                 JET '23 - Scarpe da basket - black
# 21  INFINITE - Scarpe da corsa su strada - black/a...
# 22  FAT TIRE VENTURE PRO UNISEX - Scarpe da allena...
# 23  REIGN 6 - Scarpe da allenamento - white/distan...
# 24    M1000 UNISEX - Sneakers basse - silver metallic
# 25                UNISEX - Sneakers basse - sea stone
# 26      M1000 UNISEX - Sneakers basse - dark ice wine
# 27        M1000 UNISEX  - Sneakers basse - reflection
# 28              M1000 UNISEX - Sneakers basse - black
# 29      ESSENTIALS HOODIE UNISEX - Felpa - faded plum
# 30           ESSENTIALS HOODIE UNISEX - Felpa - black
# 31   ESSENTIALS HOODIE UNISEX - Felpa - athletic grey
# 32     ESSENTIALS UNISEX - T-shirt basic - faded plum
# 33  ESSENTIALS LOGO UNISEX - T-shirt con stampa - ...
# 34  SPORT ESSENTIALS JOGGER - Pantaloni sportivi -...
# 35  ATHLETICS PACKABLE JACKET - Giacca leggera - s...
# 36   ESSENTIALS LOGO FULL ZIP - Felpa con zip - black
# 37  ESSENTIALS LOGO FULL ZIP - Felpa con zip - ath...
# 38  ULTRABOOST 5 - Scarpe da corsa su strada - bla...
# 39  SUPERNOVA RISE 2  - Scarpe da corsa su strada ...
# 40  ULTRABOOST 5 - Scarpe da corsa su strada - foo...
# 41  ULTRABOOST 5 - Scarpe da corsa su strada - foo...
# 42  ULTRABOOST 5 - Scarpe da corsa su strada - cor...
# 43  ADISTAR 3 - Scarpe da corsa su strada - white/...
# 44  SUPERNOVA RISE 2  - Scarpe da corsa su strada ...
# 45  ULTRABOOST 5 - Scarpe da corsa su strada - luc...
# 46  ULTRABOOST 5 - Scarpe da corsa su strada - cor...
# 47  ULTRABOOST 5 - Scarpe da corsa su strada - cor...
# 48  ADISTAR 3 - Scarpe da corsa su strada - white/...
# 49  SUPERNOVA RISE 2  - Scarpe da corsa su strada ...
# 50  ULTRABOOST 5 - Scarpe da corsa su strada - gre...
# 51  ADISTAR 3 - Scarpe da corsa su strada - core b...
# 52  SUPERNOVA RISE 2  - Scarpe da corsa su strada ...
#
#                                                taglie
# 0   [40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 45.5, 4...
# 1   [40, 41, 42, 43, 44, 44.5, 45, 45.5, 46, 47, 4...
# 2   [40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 45....
# 3   [40, 41, 42, 42.5, 43, 44, 44.5, 45, 45.5, 46,...
# 4   [40, 41, 42, 42.5, 43, 44, 44.5, 45, 46, 47, 4...
# 5    [41, 42, 42.5, 43, 44, 44.5, 45, 45.5, 46, 47.5]
# 6                      [37.5, 38, 38.5, 39, 40, 40.5]
# 7   [37.5, 38, 38.5, 39, 40, 40.5, 41, 42, 42.5, 4...
# 8                      [40, 40.5, 42.5, 43, 45.5, 46]
# 9    [41, 42, 42.5, 43, 44, 44.5, 45, 47, 47.5, 48.5]
# 10  [36, 37.5, 38, 38.5, 39, 40, 40.5, 41, 42, 42....
# 11  [40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 45....
# 12                   [41, 42, 42.5, 43, 44, 44.5, 45]
# 13             [42.5, 43, 44, 44.5, 45, 45.5, 46, 47]
# 14  [37.5, 38, 38.5, 39, 40, 40.5, 41, 42, 42.5, 4...
# 15  [36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5, 41, 4...
# 16         [41, 42, 42.5, 44, 44.5, 45, 45.5, 46, 47]
# 17         [40.5, 41, 42, 42.5, 43, 44, 45.5, 46, 47]
# 18  [40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 45.5, 4...
# 19  [40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 45....
# 20  [40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 45....
# 21  [40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 45....
# 22  [38, 38.5, 40.5, 41, 42, 42.5, 43, 44, 44.5, 4...
# 23  [41, 42, 42.5, 43, 44, 45, 45.5, 46, 47, 47.5,...
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None

# %%
df_taglie.to_csv('Under Armour Taglie.csv', index=False)

# %%
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import json
import time

def scrape_zalando_under_armour_sizes(url):
    driver = webdriver.Chrome()
    driver.get(url)
    time.sleep(5)  # Attendi che la pagina si carichi completamente
    html = driver.page_source
    driver.close()
    soup = BeautifulSoup(html, 'html.parser')

    s = soup.find("script", attrs={"id": "re-concurrent-data-hydrate"})
    if s:
        try:
            s = s.text.replace("window.__hydrationDataConsume(", "")[:-1]
            d = json.loads(s)
        except json.JSONDecodeError as e:
            print(f"Errore durante la decodifica JSON: {e}")
            return pd.DataFrame()
    else:
        print("Script con id 're-concurrent-data-hydrate' non trovato.")
        return pd.DataFrame()

    taglie_prodotti = []
    for p in d.get("graphqlCache", {}).values():
        if p.get("data") and p["data"].get("product"):
            nome = p["data"]["product"]["name"]
            taglie_disponibili = []
            if p["data"]["product"].get("simples"):
                for t in p["data"]["product"]["simples"]:
                    taglie_disponibili.append(t["size"])
            else:
                taglie_disponibili = None
            taglie_prodotti.append({"nome_prodotto": nome, "taglie": taglie_disponibili})

    return pd.DataFrame(taglie_prodotti)

# URL della pagina principale delle scarpe Under Armour da uomo su Zalando
base_url = "https://www.zalando.it/scarpe-sportive-uomo/under-armour/"

# Inizializza una lista per contenere tutti i DataFrames delle pagine
all_df_taglie = []

# Scrape della prima pagina
df_page = scrape_zalando_under_armour_sizes(base_url)
if not df_page.empty:
    all_df_taglie.append(df_page)

# Funzione per trovare l'URL della pagina successiva
def find_next_page_url(soup):
    next_page_link = soup.find('a', {'aria-label': 'Vai alla pagina successiva'})
    if next_page_link and next_page_link.get('href'):
        return "https://www.zalando.it" + next_page_link['href']
    return None

# Scrape delle pagine successive
current_url = base_url
page_num = 1
while True:
    driver = webdriver.Chrome()
    driver.get(current_url)
    time.sleep(5)
    html = driver.page_source
    driver.close()
    soup = BeautifulSoup(html, 'html.parser')

    next_page = find_next_page_url(soup)
    if next_page:
        page_num += 1
        print(f"Scraping pagina {page_num}: {next_page}")
        df_page = scrape_zalando_under_armour_sizes(next_page)
        if not df_page.empty:
            all_df_taglie.append(df_page)
        current_url = next_page
    else:
        print("Nessuna altra pagina trovata.")
        break

# Concatena tutti i DataFrames in uno solo
if all_df_taglie:
    df_taglie_totale = pd.concat(all_df_taglie, ignore_index=True)
    print("\nDataFrame df_taglie_totale (Tutte le pagine):")
    print(df_taglie_totale)
else:
    print("\nNessun dato trovato da nessuna pagina.")
# Out:
# Nessuna altra pagina trovata.
#
# DataFrame df_taglie_totale (Tutte le pagine):
#                                         nome_prodotto  \
# 0   CHARGED COMMIT TR 4 - Scarpe da allenamento - ...
# 1            COURT 96 - Scarpe da allenamento - black
# 2   PHANTOM 4 UNISEX - Scarpe da corsa su strada -...
# 3             REIGN 6 - Scarpe da allenamento - black
# 4   REIGN 6 - Scarpe da allenamento - anthracite/b...
# 5   Scarpe da corsa su strada - black anthracite c...
# 6          APPARITION - Scarpe da allenamento - white
# 7   CHARGED SPEED SWIFT - Scarpe da allenamento - ...
# 8    CHARGED SURGE 4 - Scarpe da allenamento - bianco
# 9   APPARITION - Scarpe da allenamento - black/met...
# 10  APPARITION - Scarpe da allenamento - white/cas...
# 11  REIGN 6 - Scarpe da allenamento - hydro green ...
# 12   APPARITION - Scarpe da allenamento - hydro green
# 13  FAT TIRE VENTURE PRO UNISEX - Scarpe da allena...
# 14  PHANTOM 4 UNISEX - Scarpe da corsa su strada -...
# 15  CHARGED BANDIT TR 3 - Scarpe da corsa su strad...
# 16  CHARGED COMMIT TR 4 - Scarpe da allenamento - ...
# 17                 JET '23 - Scarpe da basket - black
# 18       INFINITE - Scarpe da corsa su strada - black
# 19  CHARGED ROGUE - Scarpe da corsa su strada - sc...
# 20  CHARGED EDGE FITNESS - Scarpe da allenamento -...
# 21  CHARGED ROGUE 5 - Scarpe da corsa su strada - ...
# 22  CHARGED BANDIT TR 3 - Scarpe da corsa su strad...
# 23  FAT TIRE VENTURE PRO UNISEX - Scarpe da allena...
# 24    M1000 UNISEX - Sneakers basse - silver metallic
# 25                UNISEX - Sneakers basse - sea stone
# 26      M1000 UNISEX - Sneakers basse - dark ice wine
# 27        M1000 UNISEX  - Sneakers basse - reflection
# 28              M1000 UNISEX - Sneakers basse - black
# 29      ESSENTIALS HOODIE UNISEX - Felpa - faded plum
# 30           ESSENTIALS HOODIE UNISEX - Felpa - black
# 31   ESSENTIALS HOODIE UNISEX - Felpa - athletic grey
# 32     ESSENTIALS UNISEX - T-shirt basic - faded plum
# 33  ESSENTIALS LOGO UNISEX - T-shirt con stampa - ...
# 34  SPORT ESSENTIALS JOGGER - Pantaloni sportivi -...
# 35  ATHLETICS PACKABLE JACKET - Giacca leggera - s...
# 36   ESSENTIALS LOGO FULL ZIP - Felpa con zip - black
# 37  ESSENTIALS LOGO FULL ZIP - Felpa con zip - ath...
#
#                                                taglie
# 0   [40, 41, 42, 43, 44, 44.5, 45, 45.5, 46, 47, 4...
# 1   [40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 45....
# 2    [41, 42, 42.5, 43, 44, 44.5, 45, 45.5, 46, 47.5]
# 3   [40, 41, 42, 42.5, 43, 44, 44.5, 45, 45.5, 46,...
# 4    [40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 46, 48.5]
# 5      [41, 42, 42.5, 43, 44, 44.5, 45, 46, 47, 47.5]
# 6   [37.5, 38, 38.5, 39, 40, 40.5, 41, 42, 42.5, 4...
# 7                      [37.5, 38, 38.5, 39, 40, 40.5]
# 8                      [40, 40.5, 42.5, 43, 45.5, 46]
# 9   [36, 36.5, 37.5, 38, 38.5, 39, 40, 41, 42.5, 4...
# 10  [36, 37.5, 38, 38.5, 39, 40, 40.5, 41, 42, 42....
# 11  [40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 45....
# 12  [37.5, 38, 38.5, 39, 40, 40.5, 41, 42, 42.5, 4...
# 13   [41, 42, 42.5, 43, 44, 44.5, 45, 47, 47.5, 48.5]
# 14         [41, 42, 42.5, 44, 44.5, 45, 45.5, 46, 47]
# 15         [40.5, 41, 42, 42.5, 43, 44, 45.5, 46, 47]
# 16             [42.5, 43, 44, 44.5, 45, 45.5, 46, 47]
# 17  [40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 45....
# 18  [40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 45.5, 4...
# 19             [41, 42, 42.5, 44, 44.5, 45, 45.5, 46]
# 20                   [41, 42, 42.5, 43, 44, 44.5, 45]
# 21  [40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 45....
# 22  [40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 45....
# 23  [38, 38.5, 40.5, 41, 42, 42.5, 43, 44, 44.5, 4...
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None

# %%
import requests
import bs4
import csv

url = input("Iserisci l'URL: ")

res = requests.get(url)

try:
    res.raise_for_status()  # Solleva un'eccezione se la richiesta ha avuto problemi
except Exception as exc:
    print(f"Si è verificato questo problema: {exc}")

#Se la richiesta è andata a buon fine, parsiamo la pagina HTML
html_page = bs4.BeautifulSoup(res.text, "html.parser")

#Selezioniamo tutti gli elementi con la classe 'tile-body' (modifica in base alla struttura della pagina)
elem_html = "OBkCPz lystZ1 m3OCL3 HlZ_Tf ja2E95 IvrHht ZkIJC- u-kVXO"
sel_elem = html_page.select(elem_html)

#Se ci sono elementi trovati, estraiamo i dati e li scriviamo nel CSV
if sel_elem:
    with open("prodotti.csv", mode="w", newline="", encoding="utf-8") as csv_file:
        writer = csv.writer(csv_file)

        # Scriviamo l'intestazione del CSV
        writer.writerow(["Prodotto", "Descrizione"])

        # Cicliamo su tutti gli elementi trovati e li scriviamo nel CSV
        for i, elem in enumerate(sel_elem):
            # Estrai il testo da ciascun elemento e rimuovi spazi extra
            text_elem = elem.getText().strip()

            # Scriviamo una riga per ogni prodotto trovato
            writer.writerow([f"Prodotto {i+1}", text_elem])

    print(f"File CSV aggiornato con {len(sel_elem)} prodotti.")
else:
    print("Elemento con la classe 'tile-body' non trovato")
# Out:
# Iserisci l'URL:  https://www.zalando.it/scarpe-sportive-uomo/under-armour/
# Si è verificato questo problema: 403 Client Error: Forbidden for url: https://www.zalando.it/scarpe-sportive-uomo/under-armour/
# Elemento con la classe 'tile-body' non trovato
